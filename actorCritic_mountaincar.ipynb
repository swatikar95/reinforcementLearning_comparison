# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# C:\Users\swati\anaconda3\envs\tf1.1\lib\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\swati\anaconda3\envs\tf1.1\lib\site-packages\tensorflow\python\framework\dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\swati\anaconda3\envs\tf1.1\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\swati\anaconda3\envs\tf1.1\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\swati\anaconda3\envs\tf1.1\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\swati\anaconda3\envs\tf1.1\lib\site-packages\tensorflow\python\framework\dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 1.11.0

# %%
import tensorflow as tf 
import numpy as np
import gym

# %%
env = gym.envs.make("MountainCarContinuous-v0")

# %%
tf.reset_default_graph()

# %%
input_dims = 2
state_placeholder = tf.placeholder(tf.float32,[None,input_dims])

# %%
def value_function(state):
    n_hidden1 = 400  
    n_hidden2 = 400
    n_outputs = 1
    
    with tf.variable_scope("value_network"):
        init_xavier = tf.contrib.layers.xavier_initializer()
        
        hidden1 = tf.layers.dense(state, n_hidden1, tf.nn.elu, init_xavier)
        hidden2 = tf.layers.dense(hidden1, n_hidden2, tf.nn.elu, init_xavier) 
        V = tf.layers.dense(hidden2, n_outputs, None, init_xavier)
    return V

# %%
def policy_network(state):
    n_hidden1 = 40
    n_hidden2 = 40
    n_outputs = 1
    
    with tf.variable_scope("policy_network"):
        init_xavier = tf.contrib.layers.xavier_initializer()
        
        hidden1 = tf.layers.dense(state, n_hidden1, tf.nn.elu, init_xavier)
        hidden2 = tf.layers.dense(hidden1, n_hidden2, tf.nn.elu, init_xavier)
        mu = tf.layers.dense(hidden2, n_outputs, None, init_xavier)
        sigma = tf.layers.dense(hidden2, n_outputs, None, init_xavier)
        sigma = tf.nn.softplus(sigma) + 1e-5
        norm_dist = tf.contrib.distributions.Normal(mu, sigma)
        action_tf_var = tf.squeeze(norm_dist.sample(1), axis=0)
        action_tf_var = tf.clip_by_value(
            action_tf_var, env.action_space.low[0], 
            env.action_space.high[0])
    return action_tf_var, norm_dist

# %%
#sample from state space for state normalization
import sklearn
import sklearn.preprocessing
                                    
state_space_samples = np.array(
    [env.observation_space.sample() for x in range(10000)])
scaler = sklearn.preprocessing.StandardScaler()
scaler.fit(state_space_samples)

#function to normalize states
def scale_state(state):                 #requires input shape=(2,)
    scaled = scaler.transform([state])
    return scaled                       #returns shape =(1,2)

# %%
lr_actor = 0.00002  #set learning rates
lr_critic = 0.001

# define required placeholders
action_placeholder = tf.placeholder(tf.float32)
delta_placeholder = tf.placeholder(tf.float32)
target_placeholder = tf.placeholder(tf.float32)

action_tf_var, norm_dist = policy_network(state_placeholder)
V = value_function(state_placeholder)

# define actor (policy) loss function
loss_actor = -tf.log(norm_dist.prob(action_placeholder) + 1e-5) * delta_placeholder
training_op_actor = tf.train.AdamOptimizer(
    lr_actor, name='actor_optimizer').minimize(loss_actor)

# define critic (state-value) loss function
loss_critic = tf.reduce_mean(tf.squared_difference(
                             tf.squeeze(V), target_placeholder))
training_op_critic = tf.train.AdamOptimizer(
        lr_critic, name='critic_optimizer').minimize(loss_critic)

# %%
#training loop
gamma = 0.99
num_episodes = 300

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    episode_history = []
    for episode in range(num_episodes):
        #receive initial state from E
        state = env.reset()   # state.shape -> (2,)
        reward_total = 0 
        steps = 0
        done = False
        while (not done):
                
            #Sample action according to current policy
            #action.shape = (1,1)
            action  = sess.run(action_tf_var, feed_dict={
                          state_placeholder: scale_state(state)})
            #Execute action and observe reward & next state from E
            # next_state shape=(2,)    
            #env.step() requires input shape = (1,)
            next_state, reward, done, _ = env.step(
                                    np.squeeze(action, axis=0)) 
            steps +=1
            reward_total += reward
            #V_of_next_state.shape=(1,1)
            V_of_next_state = sess.run(V, feed_dict = 
                    {state_placeholder: scale_state(next_state)})  
            #Set TD Target
            #target = r + gamma * V(next_state)     
            target = reward + gamma * np.squeeze(V_of_next_state) 
            
            # td_error = target - V(s)
            #needed to feed delta_placeholder in actor training
            td_error = target - np.squeeze(sess.run(V, feed_dict = 
                        {state_placeholder: scale_state(state)})) 
            
            #Update actor by minimizing loss (Actor training)
            _, loss_actor_val  = sess.run(
                [training_op_actor, loss_actor], 
                feed_dict={action_placeholder: np.squeeze(action), 
                state_placeholder: scale_state(state), 
                delta_placeholder: td_error})
            #Update critic by minimizinf loss  (Critic training)
            _, loss_critic_val  = sess.run(
                [training_op_critic, loss_critic], 
                feed_dict={state_placeholder: scale_state(state), 
                target_placeholder: target})
            
            state = next_state
            #end while
        episode_history.append(reward_total)
        print("Episode: {}, Number of Steps : {}, Cumulative reward: {:0.2f}".format(
            episode, steps, reward_total))
        
        if np.mean(episode_history[-100:]) > 90 and len(episode_history) >= 101:
            print("****************Solved***************")
            print("Mean cumulative reward over 100 episodes:{:0.2f}" .format(
                np.mean(episode_history[-100:])))
# Out:
# Episode: 0, Number of Steps : 848, Cumulative reward: 62.62
# Episode: 1, Number of Steps : 891, Cumulative reward: 64.49
# Episode: 2, Number of Steps : 806, Cumulative reward: 65.39
# Episode: 3, Number of Steps : 999, Cumulative reward: -40.53
# Episode: 4, Number of Steps : 999, Cumulative reward: -41.99
# Episode: 5, Number of Steps : 620, Cumulative reward: 76.38
# Episode: 6, Number of Steps : 794, Cumulative reward: 67.89
# Episode: 7, Number of Steps : 578, Cumulative reward: 76.81
# Episode: 8, Number of Steps : 447, Cumulative reward: 82.17
# Episode: 9, Number of Steps : 873, Cumulative reward: 64.20
# Episode: 10, Number of Steps : 401, Cumulative reward: 83.79
# Episode: 11, Number of Steps : 744, Cumulative reward: 69.80
# Episode: 12, Number of Steps : 592, Cumulative reward: 76.30
# Episode: 13, Number of Steps : 809, Cumulative reward: 69.45
# Episode: 14, Number of Steps : 413, Cumulative reward: 82.41
# Episode: 15, Number of Steps : 544, Cumulative reward: 78.14
# Episode: 16, Number of Steps : 480, Cumulative reward: 81.15
# Episode: 17, Number of Steps : 453, Cumulative reward: 81.95
# Episode: 18, Number of Steps : 533, Cumulative reward: 79.22
# Episode: 19, Number of Steps : 339, Cumulative reward: 85.98
# Episode: 20, Number of Steps : 610, Cumulative reward: 74.75
# Episode: 21, Number of Steps : 260, Cumulative reward: 88.06
# Episode: 22, Number of Steps : 470, Cumulative reward: 81.48
# Episode: 23, Number of Steps : 299, Cumulative reward: 87.74
# Episode: 24, Number of Steps : 394, Cumulative reward: 80.83
# Episode: 25, Number of Steps : 376, Cumulative reward: 83.29
# Episode: 26, Number of Steps : 349, Cumulative reward: 84.91
# Episode: 27, Number of Steps : 402, Cumulative reward: 82.91
# Episode: 28, Number of Steps : 371, Cumulative reward: 82.66
# Episode: 29, Number of Steps : 621, Cumulative reward: 74.69
# Episode: 30, Number of Steps : 258, Cumulative reward: 87.95
# Episode: 31, Number of Steps : 262, Cumulative reward: 85.53
# Episode: 32, Number of Steps : 246, Cumulative reward: 87.42
# Episode: 33, Number of Steps : 329, Cumulative reward: 85.99
# Episode: 34, Number of Steps : 479, Cumulative reward: 80.51
# Episode: 35, Number of Steps : 186, Cumulative reward: 89.68
# Episode: 36, Number of Steps : 320, Cumulative reward: 84.18
# Episode: 37, Number of Steps : 253, Cumulative reward: 88.12
# Episode: 38, Number of Steps : 190, Cumulative reward: 91.31
# Episode: 39, Number of Steps : 179, Cumulative reward: 90.26
# Episode: 40, Number of Steps : 302, Cumulative reward: 87.57
# Episode: 41, Number of Steps : 186, Cumulative reward: 90.01
# Episode: 42, Number of Steps : 200, Cumulative reward: 89.78
# Episode: 43, Number of Steps : 178, Cumulative reward: 90.59
# Episode: 44, Number of Steps : 110, Cumulative reward: 94.60
# Episode: 45, Number of Steps : 169, Cumulative reward: 90.28
# Episode: 46, Number of Steps : 307, Cumulative reward: 86.67
# Episode: 47, Number of Steps : 253, Cumulative reward: 89.13
# Episode: 48, Number of Steps : 146, Cumulative reward: 92.86
# Episode: 49, Number of Steps : 270, Cumulative reward: 86.64
# Episode: 50, Number of Steps : 181, Cumulative reward: 89.42
# Episode: 51, Number of Steps : 178, Cumulative reward: 89.98
# Episode: 52, Number of Steps : 141, Cumulative reward: 92.00
# Episode: 53, Number of Steps : 179, Cumulative reward: 89.58
# Episode: 54, Number of Steps : 199, Cumulative reward: 90.29
# Episode: 55, Number of Steps : 180, Cumulative reward: 90.84
# Episode: 56, Number of Steps : 188, Cumulative reward: 88.44
# Episode: 57, Number of Steps : 111, Cumulative reward: 94.32
# Episode: 58, Number of Steps : 109, Cumulative reward: 93.83
# Episode: 59, Number of Steps : 118, Cumulative reward: 94.30
# Episode: 60, Number of Steps : 190, Cumulative reward: 90.42
# Episode: 61, Number of Steps : 181, Cumulative reward: 89.75
# Episode: 62, Number of Steps : 314, Cumulative reward: 83.95
# Episode: 63, Number of Steps : 223, Cumulative reward: 88.61
# Episode: 64, Number of Steps : 112, Cumulative reward: 93.87
# Episode: 65, Number of Steps : 192, Cumulative reward: 90.27
# Episode: 66, Number of Steps : 140, Cumulative reward: 93.79
# Episode: 67, Number of Steps : 235, Cumulative reward: 88.46
# Episode: 68, Number of Steps : 115, Cumulative reward: 92.75
# Episode: 69, Number of Steps : 178, Cumulative reward: 90.03
# Episode: 70, Number of Steps : 181, Cumulative reward: 89.25
# Episode: 71, Number of Steps : 202, Cumulative reward: 90.81
# Episode: 72, Number of Steps : 109, Cumulative reward: 93.21
# Episode: 73, Number of Steps : 206, Cumulative reward: 87.34
# Episode: 74, Number of Steps : 186, Cumulative reward: 89.96
# Episode: 75, Number of Steps : 205, Cumulative reward: 87.63
# Episode: 76, Number of Steps : 113, Cumulative reward: 92.73
# Episode: 77, Number of Steps : 105, Cumulative reward: 92.36
# Episode: 78, Number of Steps : 181, Cumulative reward: 89.12
# Episode: 79, Number of Steps : 180, Cumulative reward: 88.51
# Episode: 80, Number of Steps : 285, Cumulative reward: 86.09
# Episode: 81, Number of Steps : 108, Cumulative reward: 92.89
# Episode: 82, Number of Steps : 170, Cumulative reward: 91.22
# Episode: 83, Number of Steps : 179, Cumulative reward: 90.43
# Episode: 84, Number of Steps : 106, Cumulative reward: 93.23
# Episode: 85, Number of Steps : 137, Cumulative reward: 91.74
# Episode: 86, Number of Steps : 180, Cumulative reward: 90.94
# Episode: 87, Number of Steps : 206, Cumulative reward: 88.94
# Episode: 88, Number of Steps : 112, Cumulative reward: 93.87
# Episode: 89, Number of Steps : 105, Cumulative reward: 93.97
# Episode: 90, Number of Steps : 244, Cumulative reward: 89.44
# Episode: 91, Number of Steps : 142, Cumulative reward: 93.09
# Episode: 92, Number of Steps : 110, Cumulative reward: 93.46
# Episode: 93, Number of Steps : 142, Cumulative reward: 92.11
# Episode: 94, Number of Steps : 109, Cumulative reward: 92.93
# Episode: 95, Number of Steps : 114, Cumulative reward: 93.49
# Episode: 96, Number of Steps : 230, Cumulative reward: 88.15
# Episode: 97, Number of Steps : 117, Cumulative reward: 93.84
# Episode: 98, Number of Steps : 186, Cumulative reward: 88.31
# Episode: 99, Number of Steps : 194, Cumulative reward: 89.53
# Episode: 100, Number of Steps : 190, Cumulative reward: 87.60
# Episode: 101, Number of Steps : 188, Cumulative reward: 89.32
# Episode: 102, Number of Steps : 216, Cumulative reward: 89.77
# Episode: 103, Number of Steps : 241, Cumulative reward: 87.32
# Episode: 104, Number of Steps : 170, Cumulative reward: 90.31
# Episode: 105, Number of Steps : 221, Cumulative reward: 88.75
# Episode: 106, Number of Steps : 127, Cumulative reward: 92.92
# Episode: 107, Number of Steps : 124, Cumulative reward: 93.55
# Episode: 108, Number of Steps : 182, Cumulative reward: 89.18
# Episode: 109, Number of Steps : 184, Cumulative reward: 91.58
# Episode: 110, Number of Steps : 116, Cumulative reward: 94.27
# Episode: 111, Number of Steps : 211, Cumulative reward: 88.43
# Episode: 112, Number of Steps : 181, Cumulative reward: 90.68
# Episode: 113, Number of Steps : 196, Cumulative reward: 91.16
# Episode: 114, Number of Steps : 156, Cumulative reward: 92.81
# Episode: 115, Number of Steps : 120, Cumulative reward: 93.29
# Episode: 116, Number of Steps : 112, Cumulative reward: 92.43
# Episode: 117, Number of Steps : 113, Cumulative reward: 93.70
# Episode: 118, Number of Steps : 185, Cumulative reward: 90.29
# Episode: 119, Number of Steps : 187, Cumulative reward: 90.23
# Episode: 120, Number of Steps : 117, Cumulative reward: 93.54
# Episode: 121, Number of Steps : 179, Cumulative reward: 89.64
# Episode: 122, Number of Steps : 148, Cumulative reward: 91.64
# Episode: 123, Number of Steps : 129, Cumulative reward: 93.00
# Episode: 124, Number of Steps : 116, Cumulative reward: 92.90
# Episode: 125, Number of Steps : 138, Cumulative reward: 93.11
# ****************Solved***************
# Mean cumulative reward over 100 episodes:90.09
# Episode: 126, Number of Steps : 116, Cumulative reward: 93.11
# ****************Solved***************
# Mean cumulative reward over 100 episodes:90.17
# Episode: 127, Number of Steps : 179, Cumulative reward: 91.46
# ****************Solved***************
# Mean cumulative reward over 100 episodes:90.26
# Episode: 128, Number of Steps : 140, Cumulative reward: 92.46
# ****************Solved***************
# Mean cumulative reward over 100 episodes:90.36
# Episode: 129, Number of Steps : 116, Cumulative reward: 93.80
# ****************Solved***************
# Mean cumulative reward over 100 episodes:90.55
# Episode: 130, Number of Steps : 198, Cumulative reward: 90.59
# ****************Solved***************
# Mean cumulative reward over 100 episodes:90.57
# Episode: 131, Number of Steps : 115, Cumulative reward: 93.14
# ****************Solved***************
# Mean cumulative reward over 100 episodes:90.65
# Episode: 132, Number of Steps : 180, Cumulative reward: 90.02
# ****************Solved***************
# Mean cumulative reward over 100 episodes:90.68
# Episode: 133, Number of Steps : 112, Cumulative reward: 92.78
# ****************Solved***************
# Mean cumulative reward over 100 episodes:90.74
# Episode: 134, Number of Steps : 115, Cumulative reward: 92.62
# ****************Solved***************
# Mean cumulative reward over 100 episodes:90.87
# Episode: 135, Number of Steps : 178, Cumulative reward: 91.47
# ****************Solved***************
# Mean cumulative reward over 100 episodes:90.88
# Episode: 136, Number of Steps : 229, Cumulative reward: 87.86
# ****************Solved***************
# Mean cumulative reward over 100 episodes:90.92
# Episode: 137, Number of Steps : 148, Cumulative reward: 92.06
# ****************Solved***************
# Mean cumulative reward over 100 episodes:90.96
# Episode: 138, Number of Steps : 113, Cumulative reward: 94.01
# ****************Solved***************
# Mean cumulative reward over 100 episodes:90.99
# Episode: 139, Number of Steps : 117, Cumulative reward: 93.38
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.02
# Episode: 140, Number of Steps : 282, Cumulative reward: 87.32
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.02
# Episode: 141, Number of Steps : 212, Cumulative reward: 87.86
# ****************Solved***************
# Mean cumulative reward over 100 episodes:90.99
# Episode: 142, Number of Steps : 108, Cumulative reward: 92.63
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.02
# Episode: 143, Number of Steps : 189, Cumulative reward: 89.62
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.01
# Episode: 144, Number of Steps : 150, Cumulative reward: 91.04
# ****************Solved***************
# Mean cumulative reward over 100 episodes:90.98
# Episode: 145, Number of Steps : 154, Cumulative reward: 92.12
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.00
# Episode: 146, Number of Steps : 206, Cumulative reward: 88.23
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.01
# Episode: 147, Number of Steps : 124, Cumulative reward: 93.22
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.05
# Episode: 148, Number of Steps : 146, Cumulative reward: 91.33
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.04
# Episode: 149, Number of Steps : 152, Cumulative reward: 90.05
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.07
# Episode: 150, Number of Steps : 146, Cumulative reward: 91.23
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.09
# Episode: 151, Number of Steps : 119, Cumulative reward: 92.37
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.11
# Episode: 152, Number of Steps : 107, Cumulative reward: 94.34
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.14
# Episode: 153, Number of Steps : 137, Cumulative reward: 92.47
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.16
# Episode: 154, Number of Steps : 149, Cumulative reward: 92.31
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.19
# Episode: 155, Number of Steps : 111, Cumulative reward: 92.77
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.20
# Episode: 156, Number of Steps : 109, Cumulative reward: 92.38
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.24
# Episode: 157, Number of Steps : 103, Cumulative reward: 91.74
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.22
# Episode: 158, Number of Steps : 109, Cumulative reward: 92.21
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.20
# Episode: 159, Number of Steps : 144, Cumulative reward: 90.46
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.16
# Episode: 160, Number of Steps : 180, Cumulative reward: 88.66
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.15
# Episode: 161, Number of Steps : 115, Cumulative reward: 92.78
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.18
# Episode: 162, Number of Steps : 105, Cumulative reward: 91.87
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.26
# Episode: 163, Number of Steps : 111, Cumulative reward: 91.97
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.29
# Episode: 164, Number of Steps : 104, Cumulative reward: 91.70
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.27
# Episode: 165, Number of Steps : 146, Cumulative reward: 91.17
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.28
# Episode: 166, Number of Steps : 135, Cumulative reward: 90.66
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.25
# Episode: 167, Number of Steps : 111, Cumulative reward: 92.76
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.29
# Episode: 168, Number of Steps : 103, Cumulative reward: 92.04
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.28
# Episode: 169, Number of Steps : 113, Cumulative reward: 92.38
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.30
# Episode: 170, Number of Steps : 125, Cumulative reward: 92.06
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.33
# Episode: 171, Number of Steps : 171, Cumulative reward: 88.34
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.31
# Episode: 172, Number of Steps : 106, Cumulative reward: 92.01
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.30
# Episode: 173, Number of Steps : 120, Cumulative reward: 92.97
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.35
# Episode: 174, Number of Steps : 109, Cumulative reward: 92.12
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.37
# Episode: 175, Number of Steps : 105, Cumulative reward: 91.04
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.41
# Episode: 176, Number of Steps : 172, Cumulative reward: 89.00
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.37
# Episode: 177, Number of Steps : 105, Cumulative reward: 92.47
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.37
# Episode: 178, Number of Steps : 108, Cumulative reward: 92.83
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.41
# Episode: 179, Number of Steps : 106, Cumulative reward: 91.27
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.44
# Episode: 180, Number of Steps : 107, Cumulative reward: 91.80
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.49
# Episode: 181, Number of Steps : 107, Cumulative reward: 92.14
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.49
# Episode: 182, Number of Steps : 114, Cumulative reward: 92.75
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.50
# Episode: 183, Number of Steps : 107, Cumulative reward: 91.69
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.51
# Episode: 184, Number of Steps : 110, Cumulative reward: 91.41
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.50
# Episode: 185, Number of Steps : 102, Cumulative reward: 91.50
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.49
# Episode: 186, Number of Steps : 156, Cumulative reward: 90.11
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.49
# Episode: 187, Number of Steps : 109, Cumulative reward: 93.13
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.53
# Episode: 188, Number of Steps : 104, Cumulative reward: 91.33
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.50
# Episode: 189, Number of Steps : 114, Cumulative reward: 93.76
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.50
# Episode: 190, Number of Steps : 110, Cumulative reward: 92.98
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.53
# Episode: 191, Number of Steps : 104, Cumulative reward: 91.95
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.52
# Episode: 192, Number of Steps : 213, Cumulative reward: 86.43
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.45
# Episode: 193, Number of Steps : 109, Cumulative reward: 93.56
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.47
# Episode: 194, Number of Steps : 104, Cumulative reward: 92.09
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.46
# Episode: 195, Number of Steps : 153, Cumulative reward: 92.38
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.45
# Episode: 196, Number of Steps : 104, Cumulative reward: 91.66
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.48
# Episode: 197, Number of Steps : 112, Cumulative reward: 92.02
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.47
# Episode: 198, Number of Steps : 113, Cumulative reward: 92.86
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.51
# Episode: 199, Number of Steps : 111, Cumulative reward: 93.16
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.55
# Episode: 200, Number of Steps : 109, Cumulative reward: 93.46
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.61
# Episode: 201, Number of Steps : 114, Cumulative reward: 93.02
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.64
# Episode: 202, Number of Steps : 165, Cumulative reward: 89.67
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.64
# Episode: 203, Number of Steps : 121, Cumulative reward: 93.43
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.70
# Episode: 204, Number of Steps : 110, Cumulative reward: 92.58
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.73
# Episode: 205, Number of Steps : 109, Cumulative reward: 92.69
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.76
# Episode: 206, Number of Steps : 142, Cumulative reward: 91.44
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.75
# Episode: 207, Number of Steps : 133, Cumulative reward: 90.72
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.72
# Episode: 208, Number of Steps : 107, Cumulative reward: 92.88
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.76
# Episode: 209, Number of Steps : 113, Cumulative reward: 93.17
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.77
# Episode: 210, Number of Steps : 110, Cumulative reward: 93.75
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.77
# Episode: 211, Number of Steps : 135, Cumulative reward: 92.87
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.81
# Episode: 212, Number of Steps : 155, Cumulative reward: 89.83
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.81
# Episode: 213, Number of Steps : 179, Cumulative reward: 90.89
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.80
# Episode: 214, Number of Steps : 110, Cumulative reward: 93.24
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.81
# Episode: 215, Number of Steps : 103, Cumulative reward: 92.52
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.80
# Episode: 216, Number of Steps : 145, Cumulative reward: 90.71
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.78
# Episode: 217, Number of Steps : 107, Cumulative reward: 93.92
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.78
# Episode: 218, Number of Steps : 113, Cumulative reward: 92.70
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.81
# Episode: 219, Number of Steps : 102, Cumulative reward: 91.67
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.82
# Episode: 220, Number of Steps : 108, Cumulative reward: 92.66
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.81
# Episode: 221, Number of Steps : 105, Cumulative reward: 92.34
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.84
# Episode: 222, Number of Steps : 138, Cumulative reward: 91.28
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.84
# Episode: 223, Number of Steps : 103, Cumulative reward: 92.21
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.83
# Episode: 224, Number of Steps : 141, Cumulative reward: 92.16
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.82
# Episode: 225, Number of Steps : 107, Cumulative reward: 92.20
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.81
# Episode: 226, Number of Steps : 105, Cumulative reward: 91.81
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.80
# Episode: 227, Number of Steps : 116, Cumulative reward: 92.85
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.81
# Episode: 228, Number of Steps : 217, Cumulative reward: 86.32
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.75
# Episode: 229, Number of Steps : 103, Cumulative reward: 91.82
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.73
# Episode: 230, Number of Steps : 148, Cumulative reward: 91.63
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.74
# Episode: 231, Number of Steps : 178, Cumulative reward: 89.84
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.71
# Episode: 232, Number of Steps : 111, Cumulative reward: 92.99
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.74
# Episode: 233, Number of Steps : 199, Cumulative reward: 88.32
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.69
# Episode: 234, Number of Steps : 108, Cumulative reward: 93.57
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.70
# Episode: 235, Number of Steps : 109, Cumulative reward: 91.69
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.71
# Episode: 236, Number of Steps : 211, Cumulative reward: 88.22
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.71
# Episode: 237, Number of Steps : 108, Cumulative reward: 91.76
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.71
# Episode: 238, Number of Steps : 127, Cumulative reward: 93.89
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.71
# Episode: 239, Number of Steps : 157, Cumulative reward: 90.84
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.68
# Episode: 240, Number of Steps : 109, Cumulative reward: 92.30
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.73
# Episode: 241, Number of Steps : 146, Cumulative reward: 91.82
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.77
# Episode: 242, Number of Steps : 146, Cumulative reward: 92.02
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.76
# Episode: 243, Number of Steps : 192, Cumulative reward: 88.96
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.76
# Episode: 244, Number of Steps : 140, Cumulative reward: 91.28
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.76
# Episode: 245, Number of Steps : 140, Cumulative reward: 91.12
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.75
# Episode: 246, Number of Steps : 108, Cumulative reward: 91.69
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.78
# Episode: 247, Number of Steps : 163, Cumulative reward: 91.44
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.77
# Episode: 248, Number of Steps : 105, Cumulative reward: 92.58
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.78
# Episode: 249, Number of Steps : 114, Cumulative reward: 92.86
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.81
# Episode: 250, Number of Steps : 102, Cumulative reward: 91.50
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.81
# Episode: 251, Number of Steps : 111, Cumulative reward: 93.22
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.82
# Episode: 252, Number of Steps : 216, Cumulative reward: 87.50
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.75
# Episode: 253, Number of Steps : 200, Cumulative reward: 88.01
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.71
# Episode: 254, Number of Steps : 110, Cumulative reward: 92.63
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.71
# Episode: 255, Number of Steps : 135, Cumulative reward: 93.81
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.72
# Episode: 256, Number of Steps : 171, Cumulative reward: 89.68
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.69
# Episode: 257, Number of Steps : 111, Cumulative reward: 92.65
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.70
# Episode: 258, Number of Steps : 157, Cumulative reward: 93.30
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.71
# Episode: 259, Number of Steps : 166, Cumulative reward: 90.23
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.71
# Episode: 260, Number of Steps : 106, Cumulative reward: 93.90
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.76
# Episode: 261, Number of Steps : 146, Cumulative reward: 91.63
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.75
# Episode: 262, Number of Steps : 177, Cumulative reward: 89.58
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.73
# Episode: 263, Number of Steps : 110, Cumulative reward: 93.34
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.74
# Episode: 264, Number of Steps : 111, Cumulative reward: 94.16
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.77
# Episode: 265, Number of Steps : 109, Cumulative reward: 93.02
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.78
# Episode: 266, Number of Steps : 180, Cumulative reward: 92.38
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.80
# Episode: 267, Number of Steps : 156, Cumulative reward: 93.05
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.80
# Episode: 268, Number of Steps : 132, Cumulative reward: 94.02
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.82
# Episode: 269, Number of Steps : 145, Cumulative reward: 93.04
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.83
# Episode: 270, Number of Steps : 109, Cumulative reward: 93.35
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.84
# Episode: 271, Number of Steps : 143, Cumulative reward: 92.29
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.88
# Episode: 272, Number of Steps : 102, Cumulative reward: 91.82
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.88
# Episode: 273, Number of Steps : 187, Cumulative reward: 87.60
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.83
# Episode: 274, Number of Steps : 157, Cumulative reward: 91.34
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.82
# Episode: 275, Number of Steps : 104, Cumulative reward: 92.03
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.83
# Episode: 276, Number of Steps : 136, Cumulative reward: 92.36
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.86
# Episode: 277, Number of Steps : 173, Cumulative reward: 89.52
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.83
# Episode: 278, Number of Steps : 178, Cumulative reward: 89.07
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.80
# Episode: 279, Number of Steps : 173, Cumulative reward: 89.70
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.78
# Episode: 280, Number of Steps : 179, Cumulative reward: 90.06
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.76
# Episode: 281, Number of Steps : 182, Cumulative reward: 93.16
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.77
# Episode: 282, Number of Steps : 114, Cumulative reward: 93.91
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.79
# Episode: 283, Number of Steps : 143, Cumulative reward: 92.79
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.80
# Episode: 284, Number of Steps : 116, Cumulative reward: 94.33
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.83
# Episode: 285, Number of Steps : 121, Cumulative reward: 95.13
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.86
# Episode: 286, Number of Steps : 113, Cumulative reward: 94.53
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.91
# Episode: 287, Number of Steps : 109, Cumulative reward: 94.76
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.92
# Episode: 288, Number of Steps : 106, Cumulative reward: 92.43
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.93
# Episode: 289, Number of Steps : 105, Cumulative reward: 94.37
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.94
# Episode: 290, Number of Steps : 148, Cumulative reward: 92.99
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.94
# Episode: 291, Number of Steps : 177, Cumulative reward: 91.97
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.94
# Episode: 292, Number of Steps : 190, Cumulative reward: 89.19
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.97
# Episode: 293, Number of Steps : 221, Cumulative reward: 88.98
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.92
# Episode: 294, Number of Steps : 177, Cumulative reward: 93.43
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.93
# Episode: 295, Number of Steps : 108, Cumulative reward: 93.14
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.94
# Episode: 296, Number of Steps : 114, Cumulative reward: 94.09
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.97
# Episode: 297, Number of Steps : 151, Cumulative reward: 92.44
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.97
# Episode: 298, Number of Steps : 122, Cumulative reward: 94.51
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.99
# Episode: 299, Number of Steps : 135, Cumulative reward: 91.40
# ****************Solved***************
# Mean cumulative reward over 100 episodes:91.97
